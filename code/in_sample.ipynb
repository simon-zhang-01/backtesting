# %% [markdown]
# <h1 align='center'>In Sample Data Pre</h1>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data_ff.csv")
data
# Out:
# /tmp/ipykernel_189807/1978302743.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data_ff.csv")
#        Unnamed: 0.1  Unnamed: 0  PERMNO      date    NAMEENDT  \
# 0                 0        1467   10097  19960430  19960425.0
# 1                 1      286181   61209  19960430  20020101.0
# 2                 2      298578   62594  19960430  19960412.0
# 3                 3      317541   66245  19960430  20011031.0
# 4                 4      319608   66683  19960430  20020101.0
# ...             ...         ...     ...       ...         ...
# 42347         42347      518171   88159  20001130  19901114.0
# 42348         42348      519578   88232  20001130  20020101.0
# 42349         42349      519976   88281  20001130  19980903.0
# 42350         42350      521595   88378  20001130  20211231.0
# 42351         42351      522483   88519  20001130  19870623.0
#
# ...

# %%
in_sample = data[data["date_merge"] <= '2009-01-01']
out_sample = data[data['date_merge'] > '2009-01-01']

# %%
in_sample
# Out:
#        Unnamed: 0.1  Unnamed: 0  PERMNO      date    NAMEENDT  \
# 0                 0        1467   10097  19960430  19960425.0
# 1                 1      286181   61209  19960430  20020101.0
# 2                 2      298578   62594  19960430  19960412.0
# 3                 3      317541   66245  19960430  20011031.0
# 4                 4      319608   66683  19960430  20020101.0
# ...             ...         ...     ...       ...         ...
# 42347         42347      518171   88159  20001130  19901114.0
# 42348         42348      519578   88232  20001130  20020101.0
# 42349         42349      519976   88281  20001130  19980903.0
# 42350         42350      521595   88378  20001130  20211231.0
# 42351         42351      522483   88519  20001130  19870623.0
#
#                               COMNAM     CUSIP   NWPERM      PRC       VOL  \
# 0       FACELIFTERS HOME SYSTEMS INC  30303130  75149.0  18.5000    3464.0
# ...

# %%
out_sample
# Out:
#        Unnamed: 0.1  Unnamed: 0  PERMNO      date    NAMEENDT  \
# 41               41        4035   10205  20101130  20101130.0
# 42               42       51189   13603  20101130  20101130.0
# 43               43       83926   18091  20101130  20120501.0
# 44               44      122572   24248  20101130  20190801.0
# 45               45      155668   29938  20101130  20140107.0
# ...             ...         ...     ...       ...         ...
# 31982         31982      571148   93014  20101029  20060502.0
# 31983         31983      571281   93035  20101029  20050224.0
# 31984         31984      571545   93079  20101029  20080229.0
# 31985         31985      574054   93419  20101029  20021028.0
# 31986         31986      574055   93419  20101029  20021028.0
#
#                                  COMNAM     CUSIP   NWPERM    PRC      VOL  \
# 41                           L S B CORP  50215P10      0.0  20.95    292.0
# ...

# %%
in_sample.to_csv("in_sample.csv")
out_sample.to_csv("out_sample.csv")
